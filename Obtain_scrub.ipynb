# %% [markdown]
# # Import Libraries

# %%
from google.cloud import bigquery
from google.oauth2 import service_account
import os
import pandas as pd

# %% [markdown]
# # Obtain Data

# %% [markdown]
# Create BigQuery client

# %%
os.environ["GOOGLE_APPLICATION_CREDENTIALS"]= 'world-bank-indicators-3ccb8c5c2658.json'
client = bigquery.Client()

# %% [markdown]
# Get census bureau international dataset

# %%
dataset_id = client.dataset("census_bureau_international", project="bigquery-public-data")
dataset = client.get_dataset(dataset_id)

# %% [markdown]
# View census bureau international dataset tables

# %%
tables = list(client.list_tables(dataset))
for table in tables:
    print(table.table_id)
# Out:
# age_specific_fertility_rates
# birth_death_growth_rates
# country_names_area
# midyear_population
# midyear_population_5yr_age_sex
# midyear_population_age_sex
# midyear_population_agespecific
# mortality_life_expectancy

# %% [markdown]
# Get fertility rates table

# %%
table_id = dataset_id.table("age_specific_fertility_rates")
table = client.get_table(table_id)
[print(item) for item in table.schema]
client.list_rows(table, max_results=5).to_dataframe()
# Out:
# SchemaField('country_code', 'STRING', 'REQUIRED', 'Federal Information Processing Standard (FIPS) country/area code', (), None)
# SchemaField('country_name', 'STRING', 'NULLABLE', 'Country or area name', (), None)
# SchemaField('year', 'INTEGER', 'REQUIRED', 'Year', (), None)
# SchemaField('fertility_rate_15_19', 'FLOAT', 'NULLABLE', 'Age specific fertility rate for age 15-19 (births per 1,000 population)', (), None)
# SchemaField('fertility_rate_20_24', 'FLOAT', 'NULLABLE', 'Age specific fertility rate for age 20-24 (births per 1,000 population)', (), None)
# SchemaField('fertility_rate_25_29', 'FLOAT', 'NULLABLE', 'Age specific fertility rate for age 25-29 (births per 1,000 population)', (), None)
# SchemaField('fertility_rate_30_34', 'FLOAT', 'NULLABLE', 'Age specific fertility rate for age 30-34 (births per 1,000 population)', (), None)
# SchemaField('fertility_rate_35_39', 'FLOAT', 'NULLABLE', 'Age specific fertility rate for age 35-39 (births per 1,000 population)', (), None)
# SchemaField('fertility_rate_40_44', 'FLOAT', 'NULLABLE', 'Age specific fertility rate for age 40-44 (births per 1,000 population)', (), None)
# SchemaField('fertility_rate_45_49', 'FLOAT', 'NULLABLE', 'Age specific fertility rate for age 45-49 (births per 1,000 population)', (), None)
# SchemaField('total_fertility_rate', 'FLOAT', 'NULLABLE', 'Total fertility rate (lifetime births per woman)', (), None)
# SchemaField('gross_reproduction_rate', 'FLOAT', 'NULLABLE', 'Gross reproduction rate (lifetime female births per woman)', (), None)
# SchemaField('sex_ratio_at_birth', 'FLOAT', 'NULLABLE', 'Sex ratio at birth (male births per female birth)', (), None)
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/google/cloud/bigquery/table.py:1690: UserWarning: Cannot use bqstorage_client if max_results is set, reverting to fetching data with the REST endpoint.
#   if not self._validate_bqstorage(bqstorage_client, create_bqstorage_client):
#   country_code country_name  year  fertility_rate_15_19  fertility_rate_20_24  \
# 0           AA        Aruba  1981                  39.0                 118.0
# 1           AA        Aruba  1982                  41.8                 119.9
# 2           AA        Aruba  1983                  44.6                 121.9
# 3           AA        Aruba  1984                  47.5                 123.9
# 4           AA        Aruba  1985                  50.3                 125.8
#
#    fertility_rate_25_29  fertility_rate_30_34  fertility_rate_35_39  \
# 0                 118.0                  75.0                  30.0
# 1                 119.3                  76.1                  30.7
# 2                 120.6                  77.2                  31.4
# 3                 121.8                  78.2                  32.1
# 4                 123.1                  79.3                  32.8
#
#    fertility_rate_40_44  fertility_rate_45_49  total_fertility_rate  \
# 0                   6.0                   1.0                1.9350
# 1                   6.0                   0.9                1.9737
# 2                   6.0                   0.8                2.0124
# 3                   6.0                   0.7                2.0511
# 4                   6.0                   0.6                2.0898
#
#    gross_reproduction_rate  sex_ratio_at_birth
# 0                   0.9762              0.9822
# 1                   0.9963              0.9811
# 2                   1.0155              0.9817
# 3                   1.0348              0.9822
# 4                   1.0552              0.9804

# %% [markdown]
# Query fertility rates data from bigquery

# %%
fertility_query = """
        SELECT country_code, country_name, year, total_fertility_rate
        FROM `bigquery-public-data.census_bureau_international.age_specific_fertility_rates`
        WHERE year < 2019"""
fertility_query_job = client.query(fertility_query)
fertility_df = fertility_query_job.to_dataframe()
fertility_df.to_csv('Excel/fertility.csv', index=False)

# %% [markdown]
# Read fertility rate data into pandas

# %%
fertility_df = pd.read_csv('Excel/fertility.csv')
print(fertility_df.shape)
fertility_df.head()
# Out:
# (7720, 4)
#   country_code country_name  year  total_fertility_rate
# 0           AA        Aruba  1981                1.9350
# 1           AA        Aruba  1982                1.9737
# 2           AA        Aruba  1983                2.0124
# 3           AA        Aruba  1984                2.0511
# 4           AA        Aruba  1985                2.0898

# %% [markdown]
# Filter fertility rates data to only include country fertility values for the most recent year

# %%
def fertility_filter(row):
    years = fertility_df[fertility_df['country_code']==row['country_code']]['year'].values
    if row['year'] == max(years):
        return 1
    else:
        return 0

most_recent_years = fertility_df.apply(fertility_filter, axis=1)
fertility_df['filter'] = most_recent_years
fertility_df_filtered = fertility_df[fertility_df['filter']==1]
fertility_df_filtered.drop(columns='filter', inplace=True)
print(fertility_df_filtered.shape)
fertility_df_filtered.head(5)
# Out:
# (228, 4)
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4169: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#     country_code          country_name  year  total_fertility_rate
# 37            AA                 Aruba  2018                1.8324
# 65            AC   Antigua and Barbuda  2018                1.9906
# 89            AE  United Arab Emirates  2018                1.7269
# 129           AF           Afghanistan  2018                5.0200
# 161           AG               Algeria  2018                2.6646

# %% [markdown]
# Create fertility df column for replacement fertility class

# %%
def fertility_class(row):
    if row['total_fertility_rate'] >= 2:
        return 1
    else:
        return 0
fertility_df_filtered['replacement'] = fertility_df_filtered.apply(fertility_class, axis=1)
fertility_df_filtered.head()
# Out:
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     country_code          country_name  year  total_fertility_rate  \
# 37            AA                 Aruba  2018                1.8324
# 65            AC   Antigua and Barbuda  2018                1.9906
# 89            AE  United Arab Emirates  2018                1.7269
# 129           AF           Afghanistan  2018                5.0200
# 161           AG               Algeria  2018                2.6646
#
#      replacement
# 37             0
# 65             0
# 89             0
# 129            1
# 161            1

# %% [markdown]
# Get world bank wdi dataset

# %%
wb_dataset_id = client.dataset("world_bank_wdi", project="bigquery-public-data")
wb_dataset = client.get_dataset(wb_dataset_id)

# %% [markdown]
# View tables in world bank dataset

# %%
wb_tables = list(client.list_tables(wb_dataset))
for table in wb_tables:
    print(table.table_id)
# Out:
# country_series_definitions
# country_summary
# footnotes
# indicators_data
# series_summary
# series_time

# %% [markdown]
# View world bank indicators_data table

# %%
indicator_table_id = wb_dataset_id.table("indicators_data")
indicator_table = client.get_table(indicator_table_id)
[print(item) for item in indicator_table.schema]
client.list_rows(indicator_table, max_results=5).to_dataframe()
# Out:
# SchemaField('country_name', 'STRING', 'NULLABLE', '', (), None)
# SchemaField('country_code', 'STRING', 'NULLABLE', '', (), None)
# SchemaField('indicator_name', 'STRING', 'NULLABLE', '', (), None)
# SchemaField('indicator_code', 'STRING', 'NULLABLE', '', (), None)
# SchemaField('value', 'FLOAT', 'NULLABLE', '', (), None)
# SchemaField('year', 'INTEGER', 'NULLABLE', '', (), None)
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/google/cloud/bigquery/table.py:1690: UserWarning: Cannot use bqstorage_client if max_results is set, reverting to fetching data with the REST endpoint.
#   if not self._validate_bqstorage(bqstorage_client, create_bqstorage_client):
#            country_name country_code  \
# 0  Syrian Arab Republic          SYR
# 1  Syrian Arab Republic          SYR
# 2  Syrian Arab Republic          SYR
# 3  Syrian Arab Republic          SYR
# 4  Syrian Arab Republic          SYR
#
#                                       indicator_name     indicator_code  \
# 0  Population in urban agglomerations of more tha...  EN.URB.MCTY.TL.ZS
# 1                                   Population, male  SP.POP.TOTL.MA.IN
# 2                                   Population, male  SP.POP.TOTL.MA.IN
# 3           Population, male (% of total population)  SP.POP.TOTL.MA.ZS
# 4   Portfolio equity, net inflows (BoP, current US$)  BX.PEF.TOTL.CD.WD
#
#           value  year
# 0  2.819893e+01  1965
# 1  2.731856e+06  1965
# 2  3.011032e+06  1968
# 3  5.057848e+01  1993
# 4  0.000000e+00  2003

# %% [markdown]
# Query country indicators from indicators_data table

# %%
indicators_query = """
        SELECT *
        FROM `bigquery-public-data.world_bank_wdi.indicators_data`
        WHERE indicator_name IN ('Population density (people per sq. km of land area)', 
                                 'GDP per capita (constant 2010 US$)',
                                 'GDP per capita growth (annual %)',
                                 'Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)',
                                 'Urban population (% of total population)',
                                 'Labor force with advanced education (% of total working-age population with advanced education)',
                                 'General government final consumption expenditure (% of GDP)',
                                 'Personal remittances, received (% of GDP)',
                                 'Prevalence of HIV, total (% of population ages 15-49)',
                                 'Self-employed, total (% of total employment) (modeled ILO estimate)')"""
indicators_query_job = client.query(indicators_query)
indicators_df = indicators_query_job.to_dataframe()
indicators_df.to_csv('Excel/indicators.csv', index=False)
# Out:
# /Users/blantj/opt/anaconda3/lib/python3.7/site-packages/google/cloud/bigquery/client.py:441: UserWarning: Cannot create BigQuery Storage client, the dependency google-cloud-bigquery-storage is not installed.
#   "Cannot create BigQuery Storage client, the dependency "

# %% [markdown]
# Read indicators.csv file into pandas indicators df

# %%
indicators_df = pd.read_csv('Excel/indicators.csv')
print(indicators_df.shape)
indicators_df.head()
# Out:
# (92395, 6)
#                                  country_name country_code  \
# 0                         East Asia & Pacific          EAS
# 1  East Asia & Pacific (IDA & IBRD countries)          TEA
# 2                                   Euro area          EMU
# 3                                      Guyana          GUY
# 4                                       Haiti          HTI
#
#                      indicator_name     indicator_code      value  year
# 0  GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG   5.739960  2007
# 1  GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG   7.615462  1996
# 2  GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG   5.436296  1962
# 3  GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG -13.136132  1982
# 4  GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG   1.248083  1968

# %% [markdown]
# Filter indicators df to only include indicator values for most recently available year

# %%
def indicator_filter(row):
    years = indicators_df[(indicators_df['country_code'] == row['country_code']
                          )&(indicators_df['indicator_code'] == row['indicator_code'])]['year'].values
    if row['year'] == max(years):
        return 1
    else:
        return 0
indicators_df['filter'] = indicators_df.apply(indicator_filter, axis=1)
indicators_df_filtered = indicators_df[indicators_df['filter']==1]
print(indicators_df_filtered.shape)
indicators_df_filtered.head()
# Out:
# (2289, 7)
#                                country_name country_code  \
# 56                               South Asia          SAS
# 60                                Greenland          GRL
# 126  Heavily indebted poor countries (HIPC)          HPC
# 157                           Venezuela, RB          VEN
# 225                       Equatorial Guinea          GNQ
#
#                        indicator_name     indicator_code     value  year  \
# 56   GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG  3.611123  2019
# 60   GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG  3.492548  2018
# 126  GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG  1.278160  2019
# 157  GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG -4.731050  2014
# 225  GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG -8.849975  2019
#
#      filter
# 56        1
# 60        1
# 126       1
# 157       1
# 225       1

# %%
indicators_df_filtered.head(5)
# Out:
#                                country_name country_code  \
# 56                               South Asia          SAS
# 60                                Greenland          GRL
# 126  Heavily indebted poor countries (HIPC)          HPC
# 157                           Venezuela, RB          VEN
# 225                       Equatorial Guinea          GNQ
#
#                        indicator_name     indicator_code     value  year  \
# 56   GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG  3.611123  2019
# 60   GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG  3.492548  2018
# 126  GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG  1.278160  2019
# 157  GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG -4.731050  2014
# 225  GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG -8.849975  2019
#
#      filter
# 56        1
# 60        1
# 126       1
# 157       1
# 225       1

# %% [markdown]
# Pivot indicators_df_filtered to include countries as rows and indicators as columns

# %%
pivoted_indicators_df = pd.pivot(indicators_df_filtered, index='country_name', columns='indicator_name', 
                                 values='value')
pivoted_indicators_df.reset_index(inplace=True)
print(pivoted_indicators_df.shape)
pivoted_indicators_df.head()
# Out:
# (263, 11)
# indicator_name    country_name  GDP per capita (constant 2010 US$)  \
# 0                  Afghanistan                          571.466641
# 1                      Albania                         5209.362832
# 2                      Algeria                         4710.583772
# 3               American Samoa                         9271.712010
# 4                      Andorra                        45887.302126
#
# indicator_name  GDP per capita growth (annual %)  \
# 0                                       0.549628
# 1                                       2.650431
# 2                                      -1.130692
# 3                                       2.470435
# 4                                       1.669680
#
# indicator_name  General government final consumption expenditure (% of GDP)  \
# 0                                                       13.123956
# 1                                                       11.531084
# 2                                                       18.602840
# 3                                                             NaN
# 4                                                             NaN
#
# indicator_name  Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)  \
# 0                                                       21.771000
# 1                                                       46.603001
# 2                                                       14.556000
# 3                                                             NaN
# 4                                                             NaN
#
# indicator_name  Labor force with advanced education (% of total working-age population with advanced education)  \
# 0                                                       64.676697
# 1                                                       62.701599
# 2                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
#
# indicator_name  Personal remittances, received (% of GDP)  \
# 0                                                4.337765
# 1                                                9.640036
# 2                                                1.054191
# 3                                                     NaN
# 4                                                     NaN
#
# indicator_name  Population density (people per sq. km of land area)  \
# 0                                                       56.937760
# 1                                                      104.612263
# 2                                                       17.730075
# 3                                                      277.325000
# 4                                                      163.842553
#
# indicator_name  Prevalence of HIV, total (% of population ages 15-49)  \
# 0                                                             0.1
# 1                                                             0.1
# 2                                                             0.1
# 3                                                             NaN
# 4                                                             NaN
#
# indicator_name  Self-employed, total (% of total employment) (modeled ILO estimate)  \
# 0                                                       82.250000
# 1                                                       54.459000
# 2                                                       31.554001
# 3                                                             NaN
# 4                                                             NaN
#
# indicator_name  Urban population (% of total population)
# 0                                                 25.754
# 1                                                 61.229
# 2                                                 73.189
# 3                                                 87.147
# 4                                                 87.984

# %% [markdown]
# Merge pivoted_indicators_df and fertility_df_filtered

# %%
merged_df = pd.merge(fertility_df_filtered, pivoted_indicators_df, how='inner', left_on='country_name', 
         right_on='country_name')
print(merged_df.shape)
merged_df.head()
# Out:
# (188, 15)
#   country_code          country_name  year  total_fertility_rate  replacement  \
# 0           AA                 Aruba  2018                1.8324            0
# 1           AC   Antigua and Barbuda  2018                1.9906            0
# 2           AE  United Arab Emirates  2018                1.7269            0
# 3           AF           Afghanistan  2018                5.0200            1
# 4           AG               Algeria  2018                2.6646            1
#
#    GDP per capita (constant 2010 US$)  GDP per capita growth (annual %)  \
# 0                        26630.205281                          1.521780
# 1                        15703.028476                          3.753873
# 2                        41420.483032                          0.225275
# 3                          571.466641                          0.549628
# 4                         4710.583772                         -1.130692
#
#    General government final consumption expenditure (% of GDP)  \
# 0                                          16.687991
# 1                                                NaN
# 2                                          13.278419
# 3                                          13.123956
# 4                                          18.602840
#
#    Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)  \
# 0                                                NaN
# 1                                                NaN
# 2                                          52.481998
# 3                                          21.771000
# 4                                          14.556000
#
#    Labor force with advanced education (% of total working-age population with advanced education)  \
# 0                                                NaN
# 1                                                NaN
# 2                                          77.567596
# 3                                          64.676697
# 4                                                NaN
#
#    Personal remittances, received (% of GDP)  \
# 0                                   1.836798
# 1                                   1.429945
# 2                                        NaN
# 3                                   4.337765
# 4                                   1.054191
#
#    Population density (people per sq. km of land area)  \
# 0                                         588.027778
# 1                                         218.831818
# 2                                         135.609110
# 3                                          56.937760
# 4                                          17.730075
#
#    Prevalence of HIV, total (% of population ages 15-49)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                0.1
# 4                                                0.1
#
#    Self-employed, total (% of total employment) (modeled ILO estimate)  \
# 0                                                NaN
# 1                                                NaN
# 2                                           3.902000
# 3                                          82.250000
# 4                                          31.554001
#
#    Urban population (% of total population)
# 0                                    43.546
# 1                                    24.506
# 2                                    86.789
# 3                                    25.754
# 4                                    73.189

# %% [markdown]
# Save final unscrubbed dataset to csv

# %%
merged_df.to_csv('Excel/unscrubbed_dataset.csv', index=False)

# %% [markdown]
# # Scrub Data

# %% [markdown]
# Read unscrubbed dataset into pandas and view df.info() overview of dataswt

# %%
unscrubbed_df = pd.read_csv('Excel/unscrubbed_dataset.csv')
unscrubbed_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188 entries, 0 to 187
# Data columns (total 15 columns):
#  #   Column                                                                                           Non-Null Count  Dtype
# ---  ------                                                                                           --------------  -----
#  0   country_code                                                                                     188 non-null    object
#  1   country_name                                                                                     188 non-null    object
#  2   year                                                                                             188 non-null    int64
#  3   total_fertility_rate                                                                             188 non-null    float64
#  4   replacement                                                                                      188 non-null    int64
#  5   GDP per capita (constant 2010 US$)                                                               183 non-null    float64
#  6   GDP per capita growth (annual %)                                                                 186 non-null    float64
#  7   General government final consumption expenditure (% of GDP)                                      168 non-null    float64
#  8   Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)  163 non-null    float64
#  9   Labor force with advanced education (% of total working-age population with advanced education)  139 non-null    float64
#  10  Personal remittances, received (% of GDP)                                                        170 non-null    float64
#  11  Population density (people per sq. km of land area)                                              186 non-null    float64
#  12  Prevalence of HIV, total (% of population ages 15-49)                                            112 non-null    float64
#  13  Self-employed, total (% of total employment) (modeled ILO estimate)                              163 non-null    float64
#  14  Urban population (% of total population)                                                         187 non-null    float64
# dtypes: float64(11), int64(2), object(2)
# memory usage: 22.2+ KB

# %% [markdown]
# Drop columns with large numbers of missing values or descriptive values not used in modeling

# %%
unscrubbed_df.drop(columns=['Prevalence of HIV, total (% of population ages 15-49)',
                           'Labor force with advanced education (% of total working-age population with advanced education)',
                            'country_code', 'country_name', 'year']
                           , inplace=True)

# %% [markdown]
# Drop rows missing more than 2 indicators

# %%
unscrubbed_df = unscrubbed_df[unscrubbed_df.isnull().apply(lambda x: sum(x), axis=1)<=2]
print(unscrubbed_df.shape)
unscrubbed_df.head()
# Out:
# (169, 10)
#    total_fertility_rate  replacement  GDP per capita (constant 2010 US$)  \
# 0                1.8324            0                        26630.205281
# 2                1.7269            0                        41420.483032
# 3                5.0200            1                          571.466641
# 4                2.6646            1                         4710.583772
# 5                1.8881            0                         5879.992654
#
#    GDP per capita growth (annual %)  \
# 0                          1.521780
# 2                          0.225275
# 3                          0.549628
# 4                         -1.130692
# 5                          1.366684
#
#    General government final consumption expenditure (% of GDP)  \
# 0                                          16.687991
# 2                                          13.278419
# 3                                          13.123956
# 4                                          18.602840
# 5                                          10.827243
#
#    Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)  \
# 0                                                NaN
# 2                                          52.481998
# 3                                          21.771000
# 4                                          14.556000
# 5                                          63.130001
#
#    Personal remittances, received (% of GDP)  \
# 0                                   1.836798
# 2                                        NaN
# 3                                   4.337765
# 4                                   1.054191
# 5                                   2.653967
#
#    Population density (people per sq. km of land area)  \
# 0                                         588.027778
# 2                                         135.609110
# 3                                          56.937760
# 4                                          17.730075
# 5                                         120.234317
#
#    Self-employed, total (% of total employment) (modeled ILO estimate)  \
# 0                                                NaN
# 2                                           3.902000
# 3                                          82.250000
# 4                                          31.554001
# 5                                          67.792000
#
#    Urban population (% of total population)
# 0                                    43.546
# 2                                    86.789
# 3                                    25.754
# 4                                    73.189
# 5                                    56.031

# %% [markdown]
# Fill missing values with column mean

# %%
unscrubbed_df.fillna(value=unscrubbed_df.mean(), axis=0, inplace=True)
unscrubbed_df.head()
# Out:
#    total_fertility_rate  replacement  GDP per capita (constant 2010 US$)  \
# 0                1.8324            0                        26630.205281
# 2                1.7269            0                        41420.483032
# 3                5.0200            1                          571.466641
# 4                2.6646            1                         4710.583772
# 5                1.8881            0                         5879.992654
#
#    GDP per capita growth (annual %)  \
# 0                          1.521780
# 2                          0.225275
# 3                          0.549628
# 4                         -1.130692
# 5                          1.366684
#
#    General government final consumption expenditure (% of GDP)  \
# 0                                          16.687991
# 2                                          13.278419
# 3                                          13.123956
# 4                                          18.602840
# 5                                          10.827243
#
#    Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)  \
# 0                                          52.654202
# 2                                          52.481998
# 3                                          21.771000
# 4                                          14.556000
# 5                                          63.130001
#
#    Personal remittances, received (% of GDP)  \
# 0                                   1.836798
# 2                                   4.847161
# 3                                   4.337765
# 4                                   1.054191
# 5                                   2.653967
#
#    Population density (people per sq. km of land area)  \
# 0                                         588.027778
# 2                                         135.609110
# 3                                          56.937760
# 4                                          17.730075
# 5                                         120.234317
#
#    Self-employed, total (% of total employment) (modeled ILO estimate)  \
# 0                                          40.922914
# 2                                           3.902000
# 3                                          82.250000
# 4                                          31.554001
# 5                                          67.792000
#
#    Urban population (% of total population)
# 0                                    43.546
# 2                                    86.789
# 3                                    25.754
# 4                                    73.189
# 5                                    56.031

# %% [markdown]
# View unscrubbed_df.info() overview of data after scrubbing

# %%
unscrubbed_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 169 entries, 0 to 186
# Data columns (total 10 columns):
#  #   Column                                                                                           Non-Null Count  Dtype
# ---  ------                                                                                           --------------  -----
#  0   total_fertility_rate                                                                             169 non-null    float64
#  1   replacement                                                                                      169 non-null    int64
#  2   GDP per capita (constant 2010 US$)                                                               169 non-null    float64
#  3   GDP per capita growth (annual %)                                                                 169 non-null    float64
#  4   General government final consumption expenditure (% of GDP)                                      169 non-null    float64
#  5   Labor force participation rate, female (% of female population ages 15+) (modeled ILO estimate)  169 non-null    float64
#  6   Personal remittances, received (% of GDP)                                                        169 non-null    float64
#  7   Population density (people per sq. km of land area)                                              169 non-null    float64
#  8   Self-employed, total (% of total employment) (modeled ILO estimate)                              169 non-null    float64
#  9   Urban population (% of total population)                                                         169 non-null    float64
# dtypes: float64(9), int64(1)
# memory usage: 14.5 KB

# %% [markdown]
# Save scrubbed data to csv file

# %%
unscrubbed_df.to_csv('Excel/scrubbed_df.csv', index=False)
